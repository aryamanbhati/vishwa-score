-- %%
CREATE CATALOG IF NOT EXISTS xscore;
USE CATALOG xscore;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
CREATE VOLUME IF NOT EXISTS xscore.bronze.kaggle_raw;
CREATE VOLUME IF NOT EXISTS xscore.bronze.govt_raw;
SHOW SCHEMAS IN xscore;
SHOW VOLUMES IN xscore.bronze;
